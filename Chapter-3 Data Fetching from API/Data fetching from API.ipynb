# %%
import pandas as pd
import requests

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=856ae16421d9489487daeb84e3eb64f7&language=en-US&page=1')

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg          [18, 80]     238
# 1   False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg          [18, 80]     278
# 2   False  /oo4PVK6AyLZN49BokxDFGyclN86.jpg          [18, 80]     240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 4   False  /vI3aUGTuRRdM7J78KIdW98LdxE5.jpg   [35, 18, 10749]   19404
# 5   False  /Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg   [16, 10751, 14]     129
# 6   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg              [18]     389
# 7   False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg   [10749, 16, 18]  372058
# 8   False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg      [35, 53, 18]  496243
# 9   False  /dqK9Hag1054tghRQSqLSfrkvQnA.jpg  [18, 28, 80, 53]     155
# 10  False  /l6hQWH9eDksNJNiXWYRkWqikOdu.jpg      [14, 18, 80]     497
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]     680
# ...

# %%
temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity']]

# %%
temp_df
# Out:
#         id                                          title  \
# 0      238                                  The Godfather
# 1      278                       The Shawshank Redemption
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4    19404                    Dilwale Dulhania Le Jayenge
# 5      129                                  Spirited Away
# 6      389                                   12 Angry Men
# 7   372058                                     Your Name.
# 8   496243                                       Parasite
# 9      155                                The Dark Knight
# 10     497                                 The Green Mile
# 11     680                                   Pulp Fiction
# 12      13                                   Forrest Gump
# 13     122  The Lord of the Rings: The Return of the King
# 14     429                 The Good, the Bad and the Ugly
# ...

# %%
#top 5
temp_df.head()
# Out:
#       id                        title  \
# 0    238                The Godfather
# 1    278     The Shawshank Redemption
# 2    240        The Godfather Part II
# 3    424             Schindler's List
# 4  19404  Dilwale Dulhania Le Jayenge
#
#                                             overview release_date  popularity
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     131.151
# 1  Framed in the 1940s for the double murder of h...   1994-09-23     126.656
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      73.394
# 3  The true story of how businessman Oskar Schind...   1993-12-15      67.885
# 4  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      45.426

# %%
#now we will do this entire process in the loop
df=pd.DataFrame() #empty data Frame
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,571):
    response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=856ae16421d9489487daeb84e3eb64f7&language=en-US&page={}')
    temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity']]
    df=df.append(temp_df,ignore_index=True)

# %%
df
# Out:
#            id                                title  \
# 0         238                        The Godfather
# 1         278             The Shawshank Redemption
# 2         240                The Godfather Part II
# 3         424                     Schindler's List
# 4       19404          Dilwale Dulhania Le Jayenge
# ...       ...                                  ...
# 31395     769                           GoodFellas
# 31396  569094  Spider-Man: Across the Spider-Verse
# 31397   11216                      Cinema Paradiso
# 31398     637                    Life Is Beautiful
# 31399     346                        Seven Samurai
#
#                                                 overview release_date  \
# 0      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1      Framed in the 1940s for the double murder of h...   1994-09-23
# 2      In the continuing saga of the Corleone crime f...   1974-12-20
# ...

# %%
pd.read_csv('MOVIES.csv')
# Out:
#        Unnamed: 0      id                                title  \
# 0               0     238                        The Godfather
# 1               1     278             The Shawshank Redemption
# 2               2     240                The Godfather Part II
# 3               3     424                     Schindler's List
# 4               4   19404          Dilwale Dulhania Le Jayenge
# ...           ...     ...                                  ...
# 11395       11395     769                           GoodFellas
# 11396       11396  569094  Spider-Man: Across the Spider-Verse
# 11397       11397   11216                      Cinema Paradiso
# 11398       11398     637                    Life Is Beautiful
# 11399       11399     346                        Seven Samurai
#
#                                                 overview release_date  \
# 0      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# ...

# %%
#we can vist the URl-rapidAPI
