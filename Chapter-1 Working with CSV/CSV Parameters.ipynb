# %% [markdown]
# 1. Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# 2. Opening a Local CSV File

# %%
df=pd.read_csv('aug_train.csv')
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# 3. Opening a CSV from a URL

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# 4. Sep Parameter

# %%
#if we are working with tsv files
pd.read_csv('movie_titles_metadata.tsv',sep='\t',names=['sno.','Movie Names','release_year','Rating','Votes','Genres'])
# Out:
#      sno.                 Movie Names release_year  Rating     Votes  \
# 0      m0  10 things i hate about you         1999     6.9   62847.0
# 1      m1  1492: conquest of paradise         1992     6.2   10421.0
# 2      m2                  15 minutes         2001     6.1   25854.0
# 3      m3       2001: a space odyssey         1968     8.4  163227.0
# 4      m4                     48 hrs.         1982     6.9   22289.0
# ..    ...                         ...          ...     ...       ...
# 612  m612                    watchmen         2009     7.8  135229.0
# 613  m613                         xxx         2002     5.6   53505.0
# 614  m614                       x-men         2000     7.4  122149.0
# 615  m615          young frankenstein         1974     8.0   57618.0
# 616  m616                   zulu dawn         1979     6.4    1911.0
#
#                                                 Genres
# 0                                 ['comedy' 'romance']
# ...

# %% [markdown]
# 5. Index Col_parameter

# %%
#coverting the coloumn into an index
pd.read_csv('aug_train.csv',index_col='enrollee_id')
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %% [markdown]
# 6. Header Parameter

# %%
#when columns names are treated as rows
pd.read_csv('train.csv',header=1)
# Out:
#        16695 Fashionable & Comfortable Bellies For Women  (Brown)  3.9  Women  \
# 0       5120  Combo Pack of 4 Casual Shoes Sneakers For Men ...    3.8    Men
# 1      18391         Cilia Mode Leo Sneakers For Women  (White)    4.4  Women
# 2        495                            Men Black Sports Sandal    4.2    Men
# 3      16408                            Men Green Sports Sandal    3.9    Men
# 4       2692                            Women Pink Flats Sandal    4.1  Women
# ...      ...                                                ...    ...    ...
# 15724  16554                          Women Maroon Heels Sandal    4.3  Women
# 15725  19600                      Women Multicolor Flats Sandal    3.9  Women
# 15726   6733                            Women Navy Flats Sandal    3.7  Women
# 15727   3889                           Red Chief Men's Sneakers    3.9    Men
# 15728  13682                           Slip On For Men  (Brown)    5.0    Men
#
# ...

# %% [markdown]
# 7. use_cols Parameter

# %%
#the paramter is used when we want some specific coloums
pd.read_csv('aug_train.csv',usecols=['enrollee_id','gender','education_level'])
# Out:
#        enrollee_id gender education_level
# 0             8949   Male        Graduate
# 1            29725   Male        Graduate
# 2            11561    NaN        Graduate
# 3            33241    NaN        Graduate
# 4              666   Male         Masters
# ...            ...    ...             ...
# 19153         7386   Male        Graduate
# 19154        31398   Male        Graduate
# 19155        24576   Male        Graduate
# 19156         5756   Male     High School
# 19157        23834    NaN  Primary School
#
# [19158 rows x 3 columns]

# %% [markdown]
# 8. squeeze Parameter

# %%
#when we want only a single column so by using this paramter we want the column will be treated as series
pd.read_csv('aug_train.csv',usecols=['enrollee_id'],squeeze=True)
# Out:
# 0         8949
# 1        29725
# 2        11561
# 3        33241
# 4          666
#          ...
# 19153     7386
# 19154    31398
# 19155    24576
# 19156     5756
# 19157    23834
# Name: enrollee_id, Length: 19158, dtype: int64

# %% [markdown]
# 9. skipsrows/nrows Paramter

# %%
#skiprows= which rows we want to skip
#nrows= how many rows we want
pd.read_csv('aug_train.csv',nrows=100)
# Out:
#     enrollee_id      city  city_development_index gender  \
# 0          8949  city_103                   0.920   Male
# 1         29725   city_40                   0.776   Male
# 2         11561   city_21                   0.624    NaN
# 3         33241  city_115                   0.789    NaN
# 4           666  city_162                   0.767   Male
# ..          ...       ...                     ...    ...
# 95        12081   city_65                   0.802   Male
# 96         7364  city_160                   0.920    NaN
# 97        11184   city_74                   0.579    NaN
# 98         7016   city_65                   0.802   Male
# 99         8695   city_11                   0.550   Male
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# ...

# %%
pd.read_csv('aug_train.csv',skiprows=[1,5])
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0            29725   city_40                   0.776   Male
# 1            11561   city_21                   0.624    NaN
# 2            33241  city_115                   0.789    NaN
# 3            21651  city_176                   0.764    NaN
# 4            28806  city_160                   0.920   Male
# ...            ...       ...                     ...    ...
# 19151         7386  city_173                   0.878   Male
# 19152        31398  city_103                   0.920   Male
# 19153        24576  city_103                   0.920   Male
# 19154         5756   city_65                   0.802   Male
# 19155        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0       No relevent experience       no_enrollment        Graduate
# 1       No relevent experience    Full time course        Graduate
# ...

# %% [markdown]
# 10. Encoding Parameter

# %%
#if we are getting the encoding error that means that means we have to change its encoding parameter
pd.read_csv('zomato.csv',encoding='latin-1')
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# 11. skip bad lines Paramter

# %%
#when we get the parser error like there are some rows with are not filled then we can use this parameter
# pd.read_csv('zomato.csv',sep=';',encoding='latin-1',error_bad_line=False)

# %% [markdown]
# 12. dtypes Parameter

# %%
#if we want to change the data type of an column
pd.read_csv('aug_train.csv',dtype={"target":int}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int32
# ...

# %% [markdown]
# 13. Handling Dates

# %%
#this parameter is used when we have to handle the dates in data. Usually dates are in the form of Objects(strings)
#so we cannot access the date in the string format , so we use "parse_dates" paramter and in this we have to list down those coloumns which we have to convert in the date format
#pd.read_csv('xyz.csv',parse_dates=['col_names'])

# %% [markdown]
# 14. Converters

# %%
def rename(name):
    if name=="Mandaluyong City":
        return "MDL city"
    else:
        return name

# %%
rename("Mandaluyong City")
# Out:
# 'MDL city'

# %%
#this parameter is used for renaming the things with the help of a fucntion
pd.read_csv('zomato.csv',encoding='latin-1',converters={"City":rename},nrows=100)
# Out:
#     Restaurant ID                      Restaurant Name  Country Code  \
# 0         6317637                     Le Petit Souffle           162
# 1         6304287                     Izakaya Kikufuji           162
# 2         6300002               Heat - Edsa Shangri-La           162
# 3         6318506                                 Ooma           162
# 4         6314302                          Sambo Kojin           162
# ..            ...                                  ...           ...
# 95       17284175                    Locos Grill & Pub           216
# 96       17284179                  Longhorn Steakhouse           216
# 97       17284197           Mikata Japanese Steakhouse           216
# 98       17284241          Shogun Japanese Steak House           216
# 99       17284390  The Catch Seafood Room & Oyster Bar           216
#
#            City                                            Address  \
# 0   Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# ...

# %% [markdown]
# 15. na_values parameter

# %%
#to detect the empty values
pd.read_csv('aug_train.csv',na_values=['Male'])
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920    NaN
# 1            29725   city_40                   0.776    NaN
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767    NaN
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878    NaN
# 19154        31398  city_103                   0.920    NaN
# 19155        24576  city_103                   0.920    NaN
# 19156         5756   city_65                   0.802    NaN
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# 16. Loading a huge dataset in CHUNKS

# %%
#dividing the data set into small chunks
dfs=pd.read_csv('aug_train.csv',chunksize=5000)

# %%
for chunk in dfs:
    print(chunk.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (5000, 14)
# (4158, 14)
